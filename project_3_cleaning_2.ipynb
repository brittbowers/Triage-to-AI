# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
df_raw_1 = pd.read_excel('data/raw_2.xlsx')
df_raw_2 = pd.read_excel('data/raw_2_other.xlsx')

# %%
df_raw_2
# Out:
#                             S2 Table  \
# 0    Feature (Post one-hot encoding)
# 1                meds_cardiovascular
# 2                              esi.2
# 3              meds_gastrointestinal
# 4                              esi.4
# 5                    meds_analgesics
# 6                      meds_vitamins
# 7        meds_psychotherapeuticdrugs
# 8                                age
# 9               employstatus.Retired
# 10            meds_antiplateletdrugs
# 11               meds_antiasthmatics
# 12               previousdispo.Admit
# 13                 meds_cardiacdrugs
# 14                    meds_diuretics
# 15          `meds_elect/caloric/h2o`
# 16                             esi.3
# 17                      n_admissions
# 18           meds_antihyperglycemics
# 19                     meds_cnsdrugs
# 20                             esi.5
# 21           previousdispo.Discharge
# 22               meds_antiarthritics
# 23         insurance_status.Self pay
# ...
